# %%
from src.observation.inst2vec import Inst2vecEncoder
from tqdm import tqdm
import numpy as np
from sklearn.utils import resample
import os
import math

# %%
data_folder = 'data/classifyapp_data'
encoder = Inst2vecEncoder()  # inst2vec 编码器
train_samples = 1500
unk_idx = encoder.unknown_vocab_element
vsamples = 0

# %%
# Data acquisition
num_classes = 104
y_train = np.empty(0, dtype=np.int32)  # training
X_train = list()
folder_data_train = os.path.join(data_folder, 'ir_train')
y_val = np.empty(0, dtype=np.int32)  # validation
X_val = list()
folder_data_val = os.path.join(data_folder, 'ir_val')
y_test = np.empty(0, dtype=np.int32)  # testing
X_test = list()
folder_data_test = os.path.join(data_folder, 'ir_test')
print('Getting file names for', num_classes, 'classes from folders:')
print(folder_data_train)
print(folder_data_val)
print(folder_data_test)
# Out:
# Getting file names for 104 classes from folders:
# data/classifyapp_data/ir_train
# data/classifyapp_data/ir_val
# data/classifyapp_data/ir_test

# %%
# 获取每个class中的ir文件列表
seed = 2025
for i in range(1, num_classes + 1):
    folder = os.path.join(folder_data_train, str(i))  # index i marks the target class
    assert os.path.exists(folder), "Folder: " + folder + ' does not exist'
    print('\ttraining  : Read file names from folder ', folder)
    listing = os.listdir(folder)
    seq_files = [os.path.join(folder, f) for f in listing]

    # training: Randomly pick programs
    # assert len(seq_files) >= train_samples, "Cannot sample " + str(train_samples) + " from " + str(
    #     len(seq_files)) + " files found in " + folder
    # X_train += resample(seq_files, replace=False, n_samples=train_samples, random_state=seed)
    # y_train = np.concatenate([y_train, np.array([int(i) - 1] * train_samples, dtype=np.int32)])  # i becomes target
    X_train += seq_files
    y_train = np.concatenate([y_train, np.array([int(i) - 1] * len(seq_files), dtype=np.int32)])  # i becomes target


    # validation: Read data file names
    folder = os.path.join(folder_data_val, str(i))
    assert os.path.exists(folder), "Folder: " + folder + ' does not exist'
    print('\tvalidation: Read file names from folder ', folder)
    listing = os.listdir(folder + '/')
    seq_files = [os.path.join(folder, f) for f in listing]

    # validation: Randomly pick programs
    if vsamples > 0:
        assert len(seq_files) >= vsamples, "Cannot sample " + str(vsamples) + " from " + str(
            len(seq_files)) + " files found in " + folder
        X_val += resample(seq_files, replace=False, n_samples=vsamples, random_state=seed)
        y_val = np.concatenate([y_val, np.array([int(i) - 1] * vsamples, dtype=np.int32)])
    else:
        assert len(seq_files) > 0, "No .rec files found in" + folder
        X_val += seq_files
        y_val = np.concatenate([y_val, np.array([int(i) - 1] * len(seq_files), dtype=np.int32)])


    # test: Read data file names
    folder = os.path.join(folder_data_test, str(i))
    assert os.path.exists(folder), "Folder: " + folder + ' does not exist'
    print('\ttest      : Read file names from folder ', folder)
    listing = os.listdir(folder + '/')
    seq_files = [os.path.join(folder, f) for f in listing]
    assert len(seq_files) > 0, "No .rec files found in" + folder
    X_test += seq_files
    y_test = np.concatenate([y_test, np.array([int(i) - 1] * len(seq_files), dtype=np.int32)])
# Out:
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/1
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/1
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/1
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/2
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/2
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/2
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/3
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/3
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/3
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/4
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/4
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/4
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/5
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/5
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/5
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/6
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/6
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/6
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/7
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/7
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/7
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/8
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/8
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/8
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/9
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/9
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/9
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/10
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/10
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/10
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/11
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/11
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/11
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/12
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/12
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/12
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/13
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/13
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/13
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/14
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/14
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/14
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/15
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/15
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/15
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/16
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/16
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/16
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/17
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/17
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/17
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/18
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/18
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/18
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/19
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/19
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/19
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/20
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/20
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/20
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/21
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/21
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/21
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/22
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/22
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/22
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/23
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/23
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/23
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/24
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/24
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/24
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/25
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/25
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/25
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/26
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/26
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/26
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/27
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/27
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/27
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/28
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/28
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/28
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/29
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/29
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/29
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/30
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/30
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/30
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/31
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/31
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/31
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/32
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/32
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/32
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/33
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/33
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/33
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/34
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/34
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/34
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/35
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/35
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/35
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/36
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/36
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/36
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/37
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/37
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/37
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/38
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/38
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/38
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/39
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/39
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/39
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/40
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/40
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/40
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/41
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/41
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/41
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/42
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/42
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/42
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/43
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/43
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/43
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/44
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/44
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/44
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/45
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/45
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/45
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/46
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/46
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/46
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/47
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/47
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/47
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/48
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/48
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/48
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/49
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/49
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/49
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/50
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/50
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/50
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/51
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/51
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/51
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/52
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/52
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/52
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/53
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/53
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/53
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/54
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/54
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/54
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/55
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/55
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/55
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/56
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/56
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/56
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/57
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/57
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/57
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/58
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/58
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/58
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/59
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/59
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/59
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/60
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/60
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/60
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/61
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/61
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/61
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/62
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/62
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/62
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/63
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/63
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/63
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/64
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/64
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/64
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/65
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/65
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/65
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/66
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/66
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/66
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/67
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/67
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/67
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/68
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/68
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/68
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/69
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/69
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/69
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/70
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/70
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/70
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/71
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/71
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/71
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/72
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/72
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/72
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/73
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/73
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/73
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/74
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/74
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/74
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/75
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/75
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/75
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/76
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/76
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/76
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/77
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/77
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/77
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/78
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/78
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/78
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/79
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/79
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/79
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/80
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/80
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/80
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/81
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/81
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/81
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/82
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/82
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/82
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/83
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/83
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/83
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/84
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/84
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/84
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/85
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/85
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/85
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/86
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/86
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/86
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/87
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/87
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/87
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/88
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/88
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/88
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/89
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/89
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/89
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/90
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/90
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/90
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/91
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/91
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/91
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/92
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/92
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/92
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/93
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/93
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/93
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/94
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/94
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/94
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/95
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/95
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/95
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/96
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/96
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/96
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/97
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/97
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/97
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/98
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/98
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/98
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/99
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/99
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/99
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/100
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/100
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/100
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/101
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/101
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/101
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/102
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/102
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/102
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/103
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/103
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/103
# 	training  : Read file names from folder  data/classifyapp_data/ir_train/104
# 	validation: Read file names from folder  data/classifyapp_data/ir_val/104
# 	test      : Read file names from folder  data/classifyapp_data/ir_test/104

# %%
len(X_train), len(y_train)
# Out:
# (221344, 221344)

# %%
def encode_srcs(input_files, dataset_name):
    """
    encode and pad source code for learning
    data_folder: folder from which to read input files
    input_files: list of strings of file names
    """

    # Get list of source file names
    num_files = len(input_files)
    num_unks = 0
    seq_lengths = list()   

    print('\n--- Preparing to read', num_files, 'input files for', dataset_name, 'data set')
    seqs = list()
    for file in tqdm(input_files, desc='Reading IR'):
        ir = encoder.preprocess(file)
        encode_ir = encoder.encode(ir)  # inst2vec编码
        seq_lengths.append(len(encode_ir))
        num_unks += encode_ir.count(unk_idx)
        seqs.append([int(s) for s in encode_ir])

    print('\tShortest sequence    : {:>5}'.format(min(seq_lengths)))
    maxlen = max(seq_lengths)
    print('\tLongest sequence     : {:>5}'.format(maxlen))
    print('\tMean sequence length : {:>5} (rounded down)'.format(math.floor(np.mean(seq_lengths))))
    print('\tNumber of \'UNK\'      : {:>5}'.format(num_unks))
    print('\tPercentage of \'UNK\'  : {:>8.4} (% among all stmts)'.format((num_unks * 100) / sum(seq_lengths)))
    print('\t\'UNK\' index          : {:>5}'.format(unk_idx))

    return seqs, maxlen

def pad_src(seqs, maxlen, unk_index):
    padded_sequences = []
    for seq in seqs:
        if len(seq) < maxlen:
            # Pad sequence if it is shorter than maxlen
            seq = seq + [unk_index] * (maxlen - len(seq))
        padded_sequences.append(seq)

    # Convert to np.array
    encoded = np.array(padded_sequences)
    return encoded

# %%
X_seq_train, maxlen_train = encode_srcs(X_train, 'training')
X_seq_val, maxlen_val = encode_srcs(X_val, 'validation')
X_seq_test, maxlen_test = encode_srcs(X_test, 'testing')
# Out:
# --- Preparing to read 221344 input files for training data set
# Reading IR: 100%|██████████| 221344/221344 [18:08<00:00, 203.26it/s]
# 	Shortest sequence    :    11
# 	Longest sequence     :  5177
# 	Mean sequence length :   188 (rounded down)
# 	Number of 'UNK'      : 13098724
# 	Percentage of 'UNK'  :    31.35 (% among all stmts)
# 	'UNK' index          :  8564
#
# --- Preparing to read 9155 input files for validation data set
# Reading IR: 100%|██████████| 9155/9155 [00:41<00:00, 221.98it/s]
# 	Shortest sequence    :    24
# 	Longest sequence     :  5053
# 	Mean sequence length :   189 (rounded down)
# 	Number of 'UNK'      : 532337
# 	Percentage of 'UNK'  :    30.69 (% among all stmts)
# 	'UNK' index          :  8564
#
# --- Preparing to read 9227 input files for testing data set
# Reading IR: 100%|██████████| 9227/9227 [00:41<00:00, 221.22it/s]
# 	Shortest sequence    :    27
# 	Longest sequence     :  3016
# 	Mean sequence length :   185 (rounded down)
# 	Number of 'UNK'      : 525984
# 	Percentage of 'UNK'  :    30.66 (% among all stmts)
# 	'UNK' index          :  8564

# %%
train_data = [{'input_ids': ids, 'labels': int(l)} for ids, l in zip(X_seq_train, y_train)]
test_data = [{'input_ids': ids, 'labels': int(l)} for ids, l in zip(X_seq_test, y_test)]
val_data = [{'input_ids': ids, 'labels': int(l)} for ids, l in zip(X_seq_val, y_val)]

# %%
from datasets import *
import pandas as pd

train_dataset = Dataset.from_list(train_data)
test_dataset = Dataset.from_list(test_data)
val_dataset = Dataset.from_list(val_data)

# %%
dataset = DatasetDict({
    'train': train_dataset,
    'test': test_dataset,
    'val': val_dataset
})

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'labels'],
#         num_rows: 221344
#     })
#     test: Dataset({
#         features: ['input_ids', 'labels'],
#         num_rows: 9227
#     })
#     val: Dataset({
#         features: ['input_ids', 'labels'],
#         num_rows: 9155
#     })
# })

# %%
dataset.save_to_disk("/root/Compiler-master/data/ClassifyAppDataset")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/221344 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/9227 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/9155 [00:00<?, ? examples/s]

# %%
dataset = load_from_disk("/root/Compiler-master/data/ClassifyAppDataset")

# %%
dataset['train'][0]
# Out:
# {'input_ids': [8564,
#   8564,
#   8564,
#   8564,
#   0,
#   8564,
#   8564,
#   8564,
#   71,
#   8564,
#   8564,
#   8564,
#   78,
#   263,
#   8564,
#   8564,
#   425,
#   204,
#   8564,
#   346,
#   904,
#   679,
#   198,
#   757,
#   536,
#   412,
#   204,
#   8564,
#   341,
#   257,
#   8564,
#   8564,
#   1012,
#   198,
#   204,
#   8564,
#   496,
#   204,
#   8564,
#   248,
#   347,
#   679,
#   198,
#   204,
#   8564,
#   525,
#   8564,
#   695,
#   216,
#   8564,
#   347,
#   431,
#   394,
#   204,
#   8564,
#   953,
#   198,
#   424,
#   204,
#   8564,
#   341,
#   257,
#   8564,
#   966,
#   216,
#   1313,
#   8564,
#   289,
#   289,
#   293,
#   3032,
#   293,
#   3032,
#   8564,
#   295,
#   425,
#   204,
#   8564,
#   248,
#   8564,
#   295,
#   8564,
#   105,
#   8564,
#   536,
#   295,
#   394,
#   204,
#   8564,
#   3032,
#   3032,
#   481,
#   8564,
#   8564,
#   8564,
#   5468,
#   8564,
#   8564,
#   217,
#   213,
#   220,
#   221,
#   182,
#   218,
#   210,
#   8564,
#   8564,
#   258,
#   8564,
#   5468,
#   8564,
#   8564,
#   262,
#   5468,
#   8564,
#   8564,
#   8564,
#   224,
#   8564,
#   8564,
#   951,
#   8564,
#   8564,
#   225,
#   204,
#   8564,
#   261,
#   232,
#   8564,
#   8564,
#   8564,
#   8564,
#   226,
#   235,
#   234,
#   204,
#   8564,
#   697,
#   8564,
#   235,
#   216,
#   8564,
#   8564,
#   229,
#   237,
#   238,
#   239,
#   8564,
#   216,
#   8564,
#   236,
#   951,
#   77,
#   8564,
#   4763,
#   263],
#  'labels': 0}

# %%
from transformers import DataCollatorWithPadding
from torch.utils.data import Dataset, DataLoader
import torch

# %%
def collate_fn(batch, padding_value=8564, max_length=512):
    input_ids, labels = [item['input_ids'] for item in batch], [item['labels'] for item in batch]
    padded_batch = []
    if max_length == None:
        max_length = max(len(item) for item in input_ids)
    
    for item in input_ids:
        padded_item = item + [padding_value] * max(0, (max_length - len(item)))
        padded_item = padded_item[:max_length]
        padded_batch.append(padded_item)
    return {"input_ids": torch.tensor(padded_batch), "label": torch.tensor(labels)}

dataloader = DataLoader(dataset['train'], batch_size=8, collate_fn=collate_fn)

# %%
next(iter(dataloader))['input_ids'].shape
# Out:
# torch.Size([8, 512])
