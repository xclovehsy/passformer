# %%
from passformer_v2 import EncoderDecoderModel
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel '.venv (Python 3.10.16)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
